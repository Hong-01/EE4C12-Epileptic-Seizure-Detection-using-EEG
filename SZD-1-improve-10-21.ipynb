# %% [markdown]
# # **EE4C12-Epileptic-Seizure-Detection-using-EEG**
#
#
#
# Group 16 Members:
#
#     1. Zhixuan Ge
#     2. Yanqi Hong

# %% [markdown]
# ## **1. **Program Preparation****

# %% [markdown]
# ### 1.1 Import Packages

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, accuracy_score, roc_curve, precision_recall_curve, PrecisionRecallDisplay, roc_auc_score, RocCurveDisplay, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint
import random
from kmeans_pytorch import kmeans, kmeans_predict
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN
import torch
from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
device = "cuda"
#device = "cpu"

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %% [markdown]
# ### 1.2 Import Data

# %%
#load data on Yanqi Hong's computer
data = pd.read_csv('E:\DATA\TUD\Master\TUD_Master_Y1\Q1\EE4C12 Machine Learning For Electrical Engineering\CodeLab\Project\S&S_SZD (1)\Data\Project_Data_EE4C12_S&S_SZD.csv')
data
# Out:
#        Patient  annotation  min|FP1-F7  min|F7-T3  min|T3-T5  min|T5-O1  \
# 0          258           1          50         61         57         53
# 1          258           1          48         62         60         46
# 2          258           1          51         60         59         45
# 3          258           1          49         58         56         42
# 4          258           1          45         57         61         41
# ...        ...         ...         ...        ...        ...        ...
# 55451    11580          -1          75         73         81         80
# 55452    11580          -1          74         74         77         71
# 55453    11580          -1          72         76         72         73
# 55454    11580          -1          77         82         74         75
# 55455    11580          -1          71         79         74         78
#
#        min|FP2-F8  min|F8-T4  min|T4-T6  min|T6-O2  ...  norm_power_HF|CZ-C4  \
# 0              39         35         39         35  ...             0.016087
# 1              38         35         39         33  ...             0.024006
# 2              38         36         40         36  ...             0.037326
# 3              36         36         41         37  ...             0.027546
# 4              35         37         41         37  ...             0.036820
# ...           ...        ...        ...        ...  ...                  ...
# 55451          66         80         77         75  ...             0.244334
# 55452          79         75         82         77  ...             0.588236
# 55453          74         76         80         76  ...             0.296041
# 55454          82         85         80         76  ...             0.440360
# 55455          80         85         81         75  ...             1.019325
#
#        norm_power_HF|C4-T4  norm_power_HF|FP1-F3  norm_power_HF|F3-C3  \
# 0                 0.066920              0.102402             0.481384
# 1                 0.064857              0.031791             0.225788
# 2                 0.100177              0.050009             0.622584
# 3                 0.107883              0.014017             0.359140
# 4                 0.182520              0.031397             0.328354
# ...                    ...                   ...                  ...
# 55451             0.625396              0.023821             0.058277
# 55452             0.743060              0.076294             0.332341
# 55453             0.770194              0.041190             0.090919
# 55454             0.720855              0.026959             0.026340
# 55455             0.735140              0.030715             0.077191
#
#        norm_power_HF|C3-P3  norm_power_HF|P3-O1  norm_power_HF|FP2-F4  \
# 0                 0.690787             0.154544              0.062533
# 1                 0.409987             0.184671              0.071133
# 2                 0.394504             0.225516              0.050673
# 3                 0.276964             0.104977              0.018042
# 4                 0.156929             0.151952              0.047532
# ...                    ...                  ...                   ...
# 55451             0.083594             0.114426              0.119654
# 55452             0.228458             0.170603              0.351418
# 55453             0.186074             0.216797              0.231053
# 55454             0.077674             0.269610              0.186769
# 55455             0.095298             0.317765              0.271859
#
#        norm_power_HF|F4-C4  norm_power_HF|C4-P4  norm_power_HF|P4-O2
# 0                 0.046460             0.066575             0.086999
# 1                 0.022369             0.079494             0.047536
# 2                 0.044906             0.102142             0.068105
# 3                 0.079467             0.078255             0.089385
# 4                 0.135071             0.098320             0.137701
# ...                    ...                  ...                  ...
# 55451             0.295364             0.185930             0.199585
# 55452             0.638666             0.490806             0.307429
# 55453             0.770637             0.285257             0.413382
# 55454             0.790173             0.473615             0.415771
# 55455             0.675646             0.506836             0.561740
#
# [55456 rows x 362 columns]

# %%
# # load data on Zhixuan's computer
# data = pd.read_csv('D:\\User\Zhixuan Ge\Onedrive TUDelft\OneDrive - Delft University of Technology\Courses\ML for EE\SZD\S&S_SZD\Project_Data_EE4C12_S&S_SZD.csv')
# data

# %% [markdown]
# ## **2. Data Preprocessing**

# %% [markdown]
# ### 2.1 Train-Test Split

# %%
# x is the features, y is the label
y = np.int32(data['annotation'].values) 
X = data.iloc[:, 2:].values # the first two columns are patient ID and annotation, which are not features


#split the data into training and testing
Shuffle_state = 42
test_size = 0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=Shuffle_state)

print(X_train.shape)
print(X_test.shape)

classification_lable = [-1,0,1] # 1 stands for seizure segment, -1 stand for non-seizure segment. 0 stands for a segment that is right at the beginning or end of a seizure
# Out:
# (41592, 360)
# (13864, 360)

# %% [markdown]
# ### 2.2 Scaling

# %%
#standardize the data
scaler = StandardScaler().fit(X_train)  # fit the scaler to the training data
X_train_scaled = scaler.transform(X_train)  # transform the training data
X_test_scaled = scaler.transform(X_test)    # transform the testing data

# %% [markdown]
# ### 2.3 Feature Selection

# %%
print("The original number of training feature is: ", X_train_scaled.shape[1])
clf_etc = ExtraTreesClassifier(random_state=Shuffle_state).fit(X_train_scaled, y_train) # fit the model
feature_importances = clf_etc.feature_importances_  # get the feature importance

plt.bar(range(len(feature_importances)), feature_importances)   # plot the feature importance
plt.xlabel("Feature index")
plt.ylabel("Feature importance")
plt.title("Feature importance of all features")
plt.show()

important_feature_indices=np.argsort(feature_importances)   # sort the feature importance  
important_feature_indices_cut=important_feature_indices[:int(len(important_feature_indices)/1.5)]   # select the most important features  

X_train_scaled=np.delete(X_train_scaled,important_feature_indices_cut,1)    # delete the least important features
X_test_scaled=np.delete(X_test_scaled,important_feature_indices_cut,1)      # delete the least important features
print("The current number of training feature after feature selection is: ", X_train_scaled.shape[1])
# Out:
# The original number of training feature is:  360
# The current number of training feature after feature selection is:  120

# %% [markdown]
# ### 2.4 Oversampling and Undersampling

# %%
num_zero=np.sum(y_train==0)
num_one=np.sum(y_train==1)
num_negatives_one=np.sum(y_train==-1)
print('The original sample number of 0 is', num_zero)
print('The original sample number of 1 is', num_one)
print('The original sample number of -1 is', num_negatives_one)

# oversampling
# sm = SMOTE(random_state=Shuffle_state)
# X_train_scaled, y_train = sm.fit_resample(X_train_scaled, y_train)

# oversampling & undersampling
smt = SMOTETomek(random_state=Shuffle_state)
# sme = SMOTEENN(random_state=42)
X_train_scaled, y_train = smt.fit_resample(X_train_scaled, y_train)


num_zero=np.sum(y_train==0)
num_one=np.sum(y_train==1)
num_negatives_one=np.sum(y_train==-1)

print('')
print('The current sample number of 0 is', num_zero)
print('The current sample number of 1 is', num_one)
print('The current sample number of -1 is', num_negatives_one)
# Out:
# The original sample number of 0 is 1469
# The original sample number of 1 is 18177
# The original sample number of -1 is 21946
#
# The current sample number of 0 is 21946
# The current sample number of 1 is 21826
# The current sample number of -1 is 21826

# %% [markdown]
# ## **3. **Model Training, validation and evaluation****

# %%
#k fold cross validation function
def Kfold_split(X_train, y_train, Shuffle_state):   # Split the data into training and validation sets
    #example : X_k_train, y_k_train, X_k_val, y_k_val = Kfold_split(X_train, y_train, Shuffle_state)
    kf = KFold(n_splits=5, random_state=Shuffle_state, shuffle=True)    # 5-fold cross validation
    kf.get_n_splits(X_train)    
    X_k_train = []
    y_k_train = []
    X_k_val = []
    y_k_val = []
    for train_index, val_index in kf.split(X_train):  # Split the data into training and validation sets
        X_k_train.append(X_train[train_index])
        y_k_train.append(y_train[train_index])
        X_k_val.append(X_train[val_index])
        y_k_val.append(y_train[val_index])
    return X_k_train, y_k_train, X_k_val, y_k_val

# %% [markdown]
# ### 3.1 Logistic regression model

# %% [markdown]
# #### 3.1.1 Model training and validation

# %%
#Logistic regression
# random search to find the best hyperparameters
clf_lr = LogisticRegression(max_iter=1000,class_weight="balanced")  # define the model
param_dist = {'C':np.arange(-4, 4, 0.5), 'penalty':['l1', 'l2']}    # define the hyperparameters

# run randomized search
n_iter_search = 10
random_search = RandomizedSearchCV(clf_lr, param_distributions=param_dist,
                                   n_iter=n_iter_search, cv=5, verbose=2, n_jobs=12) 
random_search.fit(X_train_scaled, y_train)


best_params = random_search.best_params_
best_score = random_search.best_score_
print("the best parameters are",random_search.best_params_)
print("Best score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 40 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0, inf]. Got 0.0 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0, inf]. Got -4.0 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0, inf]. Got -0.5 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0, inf]. Got -1.5 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0, inf]. Got -1.0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.69649989        nan 0.69642367        nan        nan
#         nan        nan        nan        nan]
#   warnings.warn(
# the best parameters are {'penalty': 'l2', 'C': 3.5}
# Best score: 0.6964998924014509

# %% [markdown]
# #### 3.1.2 Model validation result

# %%
clf_lr = LogisticRegression(max_iter=1000,class_weight="balanced",C=best_params['C'],penalty=best_params['penalty'])  # define the model

# 5-fold cross validation
X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)
accuracy_score_list = []

for i in range(len(X_k_train_list)):
    clf_lr.fit(X_k_train_list[i], y_k_train_list[i])
    y_pred = clf_lr.predict(X_k_val_list[i])
    accuracy_score_list.append(accuracy_score(y_k_val_list[i], y_pred))

    print("The accuracy score of the", i+1, "th fold is", accuracy_score_list[i])
    
    #plot the confusion matrix
    cm = confusion_matrix(y_k_val_list[i], y_pred, labels=classification_lable)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classification_lable) 
    disp.plot()

accuracy_score_mean = np.mean(accuracy_score_list)

print("+------------------------------------------------------+")
print("The mean of the accuracy score is", accuracy_score_mean)
print("+------------------------------------------------------+")
# Out:
# The accuracy score of the 1 th fold is 0.6941310975609756
# The accuracy score of the 2 th fold is 0.7011432926829269
# The accuracy score of the 3 th fold is 0.698780487804878
# The accuracy score of the 4 th fold is 0.6949462611479533
# The accuracy score of the 5 th fold is 0.6937266559951216
# +------------------------------------------------------+
# The mean of the accuracy score is 0.696545559038371
# +------------------------------------------------------+

# %% [markdown]
# #### 3.1.3 Model evaluation

# %%
y_pred = clf_lr.predict(X_test_scaled)
#Performance metrics
Accuracy_LR = accuracy_score(y_test, y_pred)
F1_LR = accuracy_score(y_test, y_pred)
Precision_LR = accuracy_score(y_test, y_pred)
Recall_LR = accuracy_score(y_test, y_pred)
print("Accuracy: " + str(Accuracy_LR))
print("F1 score: " + str(F1_LR))
print("Recall score: " + str(Recall_LR))
print("Precision score: " + str(Precision_LR))
# Out:
# Accuracy: 0.7125649163300635
# F1 score: 0.7125649163300635
# Recall score: 0.7125649163300635
# Precision score: 0.7125649163300635

# %%
#Confusion Matrix
cm_2c = confusion_matrix(y_test, y_pred)
cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()
plt.show()

# %% [markdown]
# #### 3.1.4 Model summary

# %%
#linear regression summary
print("-----------------Logistic Regression Summary-----------------")
print("Best parameters:", best_params)
print("Best score in cross validation process:", best_score)
print("Accuracy in validation set with best parameters: " + str(accuracy_score_mean))
print("Accuracy in test set with best parameters: " + str(Accuracy_LR))
print("-------------------------------------------------------------")
# Out:
# -----------------Logistic Regression Summary-----------------
# Best parameters: {'penalty': 'l2', 'C': 3.5}
# Best score in cross validation process: 0.6964998924014509
# Accuracy in validation set with best parameters: 0.696545559038371
# Accuracy in test set with best parameters: 0.7125649163300635
# -------------------------------------------------------------

# %% [markdown]
# ### 3.2 SVM model

# %% [markdown]
# #### 3.2.1 Model training and validation

# %%
#SVM
# random search to find the best hyperparameters
clf_svm = svm.SVC(max_iter=1000,class_weight="balanced")  # define the model
param_dist = {'C':np.arange(-4, 4, 0.5), 'kernel':['linear', 'poly', 'rbf', 'sigmoid'], 'degree':np.arange(1, 5, 1), 'gamma':['scale', 'auto']}

# # run randomized search
n_iter_search = 10
random_search = RandomizedSearchCV(clf_svm, param_distributions=param_dist,
                                   n_iter=n_iter_search, cv=5, verbose=2, n_jobs=12) 
random_search.fit(X_train_scaled, y_train)
y_pred = random_search.predict(X_test_scaled)

best_params = random_search.best_params_
best_score = random_search.best_score_
print("the best parameters are",random_search.best_params_)
print("Best score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf). Got -1.5 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf). Got -2.5 instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf). Got -0.5 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf). Got -3.0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.32990333        nan 0.3347356         nan
#  0.3440348  0.33147379        nan 0.38325961]
#   warnings.warn(
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# the best parameters are {'kernel': 'linear', 'gamma': 'scale', 'degree': 4, 'C': 1.0}
# Best score: 0.38325960857367547

# %% [markdown]
# #### 3.2.2 Model validation result

# %%
clf_svm = svm.SVC(max_iter=1000,class_weight="balanced",C=best_params['C'],kernel=best_params['kernel'],degree=best_params['degree'],gamma=best_params['gamma'])  # define the model

# 5-fold cross validation
X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)
accuracy_score_list = []

for i in range(len(X_k_train_list)):
    clf_svm.fit(X_k_train_list[i], y_k_train_list[i])
    y_pred = clf_svm.predict(X_k_val_list[i])
    accuracy_score_list.append(accuracy_score(y_k_val_list[i], y_pred))

    print("The accuracy score of the", i+1, "th fold is", accuracy_score_list[i])
    
    #plot the confusion matrix
    cm = confusion_matrix(y_k_val_list[i], y_pred, labels=classification_lable)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classification_lable) 
    disp.plot()

accuracy_score_mean = np.mean(accuracy_score_list)

print("+------------------------------------------------------+")
print("The mean of the accuracy score is", accuracy_score_mean)
print("+------------------------------------------------------+")
# Out:
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# The accuracy score of the 1 th fold is 0.26730182926829266
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# The accuracy score of the 2 th fold is 0.3673780487804878
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# The accuracy score of the 3 th fold is 0.3623475609756098
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# The accuracy score of the 4 th fold is 0.39820108239957314
# C:\Users\skyho\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# The accuracy score of the 5 th fold is 0.46344995807607287
# +------------------------------------------------------+
# The mean of the accuracy score is 0.37173569590000727
# +------------------------------------------------------+

# %% [markdown]
# #### 3.2.2 Model evaluation

# %%
y_pred = clf_svm.predict(X_test_scaled)

#Performance metrics
Accuracy_LR = accuracy_score(y_test, y_pred)
F1_LR = accuracy_score(y_test, y_pred)
Precision_LR = accuracy_score(y_test, y_pred)
Recall_LR = accuracy_score(y_test, y_pred)
print("Accuracy: " + str(Accuracy_LR))
print("F1 score: " + str(F1_LR))
print("Recall score: " + str(Recall_LR))
print("Precision score: " + str(Precision_LR))
# Out:
# Accuracy: 0.6358915175995383
# F1 score: 0.6358915175995383
# Recall score: 0.6358915175995383
# Precision score: 0.6358915175995383

# %%
#Confusion Matrix
cm_2c = confusion_matrix(y_test, y_pred)
cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()
plt.show()

# %% [markdown]
# #### 3.2.3 Model summary

# %%
#svm summary
print("-----------------SVM Summary-----------------")
print("Best parameters:", best_params)
print("Best score in cross validation process:", best_score)
print("Accuracy in validation set with best parameters: " + str(accuracy_score_mean))
print("Accuracy in test set with best parameters: " + str(Accuracy_LR))
print("-------------------------------------------------------------")
# Out:
# -----------------SVM Summary-----------------
# Best parameters: {'kernel': 'linear', 'gamma': 'scale', 'degree': 4, 'C': 1.0}
# Best score in cross validation process: 0.38325960857367547
# Accuracy in validation set with best parameters: 0.37173569590000727
# Accuracy in test set with best parameters: 0.6358915175995383
# -------------------------------------------------------------

# %% [markdown]
# ### 3.3 MLP model (based on sklearn)

# %% [markdown]
# #### 3.3.1 Model training and validation

# %%
min_width=32
max_width=256
min_depth=1
max_depth=3
hidden_layer_number=5

min_learning_rate=0.0001
max_learning_rate=0.01
learning_rate_number=3

mlp = MLPClassifier()
param_dist = {"hidden_layer_sizes": [tuple([randint(min_width,max_width).rvs() for i in range(randint(min_depth, max_depth+1).rvs())]) for j in range(hidden_layer_number)],
              "activation": ["logistic", "tanh", "relu"],
              "alpha": [randint(int(min_learning_rate*10000),int(max_learning_rate*10000)).rvs()/10000  for j in range(learning_rate_number)],
            }
print(param_dist)

# run randomized search
n_iter_search = 10
random_search = RandomizedSearchCV(mlp, param_distributions=param_dist,
                                   n_iter=n_iter_search, cv=5, verbose=2, n_jobs=10)
random_search.fit(X_train_scaled, y_train)


best_params = random_search.best_params_
best_score = random_search.best_score_
print("the best parameters are",random_search.best_params_)
print("Best score:", random_search.best_score_)
# Out:
# {'hidden_layer_sizes': [(74, 211), (214, 119), (52, 119, 179), (162, 213), (198,)], 'activation': ['logistic', 'tanh', 'relu'], 'alpha': [0.006, 0.0046, 0.0053]}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# the best parameters are {'hidden_layer_sizes': (214, 119), 'alpha': 0.0046, 'activation': 'relu'}
# Best score: 0.9391446693866092

# %% [markdown]
# #### 3.3.2 Model validation result

# %%
mlp = MLPClassifier(hidden_layer_sizes=best_params['hidden_layer_sizes'],activation=best_params['activation'],alpha=best_params['alpha'])  # define the model

# 5-fold cross validation
X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)
accuracy_score_list = []

for i in range(len(X_k_train_list)):
    mlp.fit(X_k_train_list[i], y_k_train_list[i])
    y_pred = mlp.predict(X_k_val_list[i])
    accuracy_score_list.append(accuracy_score(y_k_val_list[i], y_pred))

    print("The accuracy score of the", i+1, "th fold is", accuracy_score_list[i])
    
    #plot the confusion matrix
    cm = confusion_matrix(y_k_val_list[i], y_pred, labels=classification_lable)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classification_lable) 
    disp.plot()

accuracy_score_mean = np.mean(accuracy_score_list)

print("+------------------------------------------------------+")
print("The mean of the accuracy score is", accuracy_score_mean)
print("+------------------------------------------------------+")
# Out:
# The accuracy score of the 1 th fold is 0.9439024390243902
# The accuracy score of the 2 th fold is 0.9407012195121951
# The accuracy score of the 3 th fold is 0.9407774390243903
# The accuracy score of the 4 th fold is 0.9344462230352923
# The accuracy score of the 5 th fold is 0.9326168153060447
# +------------------------------------------------------+
# The mean of the accuracy score is 0.9384888271804626
# +------------------------------------------------------+

# %% [markdown]
# #### 3.3.2 Model evaluation

# %%
y_pred = mlp.predict(X_test_scaled)
#Performance metrics
Accuracy_LR = accuracy_score(y_test, y_pred)
F1_LR = accuracy_score(y_test, y_pred)
Precision_LR = accuracy_score(y_test, y_pred)
Recall_LR = accuracy_score(y_test, y_pred)
print("Accuracy: " + str(Accuracy_LR))
print("F1 score: " + str(F1_LR))
print("Recall score: " + str(Recall_LR))
print("Precision score: " + str(Precision_LR))
# Out:
# Accuracy: 0.865334679746105
# F1 score: 0.865334679746105
# Recall score: 0.865334679746105
# Precision score: 0.865334679746105

# %%
#Confusion Matrix
cm_2c = confusion_matrix(y_test, y_pred)
cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()
plt.show()

# %% [markdown]
# #### 3.3.3 Model summary

# %%
# mlp summary
print("-----------------MLP Summary-----------------")
print("Best parameters:", best_params)
print("Best score in cross validation process:", best_score)
print("Accuracy in validation set with best parameters: " + str(accuracy_score_mean))
print("Accuracy in test set best parameters: " + str(Accuracy_LR))
print("-------------------------------------------------------------")
# Out:
# -----------------MLP Summary-----------------
# Best parameters: {'hidden_layer_sizes': (214, 119), 'alpha': 0.0046, 'activation': 'relu'}
# Best score in cross validation process: 0.9391446693866092
# Accuracy in validation set with best parameters: 0.9384888271804626
# Accuracy in test set best parameters: 0.865334679746105
# -------------------------------------------------------------

# %% [markdown]
# ### 3.4 Random Forest

# %% [markdown]
# #### 3.4.1 Model training and validation

# %%
rf = RandomForestClassifier()
param_dist = {"max_depth": [3,4,5,None],
              "max_features": ["sqrt", "log2", None],
              "min_samples_split": np.arange(2, 10),
              "criterion": ["gini", "entropy", "log_loss"]}

# run randomized search
n_iter_search = 10
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,
                                   n_iter=n_iter_search, cv=5, verbose=3, n_jobs=8)

random_search.fit(X_train_scaled, y_train)  # fit the model

best_params = random_search.best_params_
best_score = random_search.best_score_
print("the best parameters are",best_params)
print("Best score:", best_score)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# the best parameters are {'min_samples_split': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# Best score: 0.932406563557975

# %% [markdown]
# #### 3.4.2 Model validation result

# %%
rf = RandomForestClassifier(max_depth=best_params['max_depth'],max_features=best_params['max_features'],min_samples_split=best_params['min_samples_split'],criterion=best_params['criterion'])  # define the model

# 5-fold cross validation
X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)
accuracy_score_list = []

for i in range(len(X_k_train_list)):
    rf.fit(X_k_train_list[i], y_k_train_list[i])
    y_pred = rf.predict(X_k_val_list[i])
    accuracy_score_list.append(accuracy_score(y_k_val_list[i], y_pred))

    print("The accuracy score of the", i+1, "th fold is", accuracy_score_list[i])
    
    #plot the confusion matrix
    cm = confusion_matrix(y_k_val_list[i], y_pred, labels=classification_lable)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classification_lable) 
    disp.plot()

accuracy_score_mean = np.mean(accuracy_score_list)

print("+------------------------------------------------------+")
print("The mean of the accuracy score is", accuracy_score_mean)
print("+------------------------------------------------------+")
# Out:
# The accuracy score of the 1 th fold is 0.9316310975609756
# The accuracy score of the 2 th fold is 0.9342225609756097
# The accuracy score of the 3 th fold is 0.9348323170731707
# The accuracy score of the 4 th fold is 0.9301776050003812
# The accuracy score of the 5 th fold is 0.9301013796783292
# +------------------------------------------------------+
# The mean of the accuracy score is 0.9321929920576932
# +------------------------------------------------------+

# %% [markdown]
# #### 3.4.2 Model evaluation

# %%
y_pred = rf.predict(X_test_scaled)
#Performance metrics
Accuracy_LR = accuracy_score(y_test, y_pred)
F1_LR = accuracy_score(y_test, y_pred)
Precision_LR = accuracy_score(y_test, y_pred)
Recall_LR = accuracy_score(y_test, y_pred)
print("Accuracy: " + str(Accuracy_LR))
print("F1 score: " + str(F1_LR))
print("Recall score: " + str(Recall_LR))
print("Precision score: " + str(Precision_LR))
# Out:
# Accuracy: 0.8682919792267744
# F1 score: 0.8682919792267744
# Recall score: 0.8682919792267744
# Precision score: 0.8682919792267744

# %%
#Confusion Matrix
cm_2c = confusion_matrix(y_test, y_pred)
cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()
plt.show()

# %% [markdown]
# #### 3.4.3 Model summary

# %%
# random forest summary
print("-----------------Random Forest Summary-----------------")
print("Best parameters:", best_params)
print("Best score in cross validation process:", best_score)
print("Accuracy in validation set with best parameters: " + str(accuracy_score_mean))
print("Accuracy in test set with best parameters: " + str(Accuracy_LR))
print("-------------------------------------------------------------")
# Out:
# -----------------Random Forest Summary-----------------
# Best parameters: {'min_samples_split': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# Best score in cross validation process: 0.932406563557975
# Accuracy in validation set with best parameters: 0.9321929920576932
# Accuracy in test set with best parameters: 0.8682919792267744
# -------------------------------------------------------------

# %% [markdown]
# ### 3.4  DNN model (based on PyTorch)

# %% [markdown]
# #### 3.4.1 Model definition

# %%
# initialize the NN
class Data_tensor(Dataset):
    def __init__(self, X, y):
        X = np.float32(X)
        X = torch.from_numpy(X)
        y = np.longlong(y) - y.min()
        y = torch.from_numpy(y)
        
        self.X = X.to(device)
        self.y = y.to(device)
        
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# DNN class for random search
class DNN_rs(nn.Module):
    # Available activation functions: ReLU, Sigmoid, Tanh, LeakyReLU, ELU, SELU, Softplus, Softsign, LogSigmoid, PReLU, Softmin, Softmax, if the input is not in the list, ReLU will be used
    def __init__(self, input_size, hidden_sizes, output_size, activition_layer=nn.ReLU()):
        super(DNN_rs, self).__init__()
        depth=len(hidden_sizes)
        layers = []
        for i in range(depth):
            if i == 0:
                layers.append(nn.Linear(input_size, hidden_sizes[i])) 
            else:
                layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
            if activition_layer=="ReLU":
                layers.append(nn.ReLU())
            elif activition_layer=="Sigmoid":
                layers.append(nn.Sigmoid())
            elif activition_layer=="Tanh":
                layers.append(nn.Tanh())
            elif activition_layer=="LeakyReLU":
                layers.append(nn.LeakyReLU())
            elif activition_layer=="ELU":
                layers.append(nn.ELU())
            elif activition_layer=="SELU":
                layers.append(nn.SELU())
            elif activition_layer=="Softplus":
                layers.append(nn.Softplus())
            elif activition_layer=="Softsign":
                layers.append(nn.Softsign())
            elif activition_layer=="LogSigmoid":
                layers.append(nn.LogSigmoid())
            elif activition_layer=="PReLU":
                layers.append(nn.PReLU())
            elif activition_layer=="Softmin":
                layers.append(nn.Softmin())
            elif activition_layer=="Softmax":
                layers.append(nn.Softmax())
            else:
                layers.append(nn.ReLU())
        layers.append(nn.Linear( hidden_sizes[-1], output_size))
        self.linear_relu_stack = nn.Sequential(*layers)

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Test output for DNN_rs
input_size = X_train_scaled.shape[1]
output_size = 3
model_rs = DNN_rs(input_size, hidden_sizes=[512,512], output_size=output_size, activition_layer="PReLU").to(device)
print(model_rs)

optimizer = torch.optim.Adam(model_rs.parameters(), lr=0.001)
# Out:
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=512, bias=True)
#     (1): PReLU(num_parameters=1)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): PReLU(num_parameters=1)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# Train and test functions
def train(dataloader, model, loss_fn, optimizer):  
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        # print(pred.dtype)
        # print(y.dtype)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>5f}  [{current:>5d}/{size:>5d}]")
            
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
# Define loss function and optimizer
loss_fn = nn.CrossEntropyLoss() # CrossEntropyLoss for multi-classification
# optimizer_rs = torch.optim.Adam(model_rs.parameters(),weight_decay=0.005)   # Adam optimizer for random search

# %% [markdown]
# #### 3.4.2 Model training and validation

# %%
# Random search for DNN
min_width=32
max_width=650
min_depth=1
max_depth=5
hidden_layer_number=12

min_learning_rate=0.0001
max_learning_rate=0.01
learning_rate_number=8

activition_list=["ReLU", "LogSigmoid", "LeakyReLU","Sigmoid"]

input_size=X_train_scaled.shape[1]
output_size=3

epochs = 6

param_dist = {"hidden_sizes": [[randint(min_width,max_width).rvs() for i in range(randint(min_depth, max_depth+1).rvs())] for j in range(hidden_layer_number)], 
                                "alpha": [randint(int(min_learning_rate*10000),int(max_learning_rate*10000)).rvs()/10000  for j in range(learning_rate_number)], # L2 regularization
                                "activition": activition_list,
                            }

print(param_dist["hidden_sizes"])
print(param_dist["alpha"])
print(param_dist["activition"])

train_dataloader_list = []
val_dataloader_list = []

accuracy_list=[]

parameters_list=[]

progress=0

X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)   # K-fold cross validation for DNN
for i in range(len(X_k_train_list)):
    
    print("#"*20)
    print("Fold " + str(i+1))
    print("#"*20)

    batch_size = 1024
    trainset_gpu = Data_tensor(X_k_train_list[i], y_k_train_list[i])
    valset_gpu = Data_tensor(X_k_val_list[i], y_k_val_list[i])
    train_dataloader = DataLoader(trainset_gpu, batch_size=batch_size, shuffle=True)
    validation_dataloader = DataLoader(valset_gpu, batch_size=batch_size, shuffle=False)
    
    for m in range(hidden_layer_number):
        hidden_layer=param_dist['hidden_sizes'][m]
        for j in param_dist['alpha']:
            alpha=j
            for k in param_dist['activition']:
                progress+=1
                activition_layer=k
                print("*"*20)
                print("hidden size: ", hidden_layer)
                print("learning rate: ", alpha)
                print("activition layer: ", activition_layer)
                print("*"*20)
                print("Training Progress: "+ str(progress)+" / "+str(len(X_k_train_list)*hidden_layer_number*len(param_dist['alpha'])*len(param_dist['activition'])))
                print("*"*20)
                parameters_list.append([hidden_layer,alpha, activition_layer])

                model_rs = DNN_rs(input_size, hidden_layer, output_size, activition_layer).to(device)
                optimizer_rs= torch.optim.Adam(model_rs.parameters(), lr=alpha,weight_decay=0.005)
                print(model_rs)

                print(train_dataloader.dataset[:][0])
                for t in range(epochs):
                    print(f"Epoch {t+1}\n-------------------------------")
                    train(train_dataloader, model_rs, loss_fn, optimizer_rs)
                    test(validation_dataloader, model_rs, loss_fn)
                print("Done!")

                model_rs.eval()
                pred = model_rs(validation_dataloader.dataset[:][0]).detach().cpu().max(axis=1).indices.numpy()
                true = validation_dataloader.dataset[:][1].cpu().numpy()
                # Performance metrics
                Accuracy_LR = accuracy_score(true, pred)
                F1_LR = accuracy_score(true, pred)
                Precision_LR = accuracy_score(true, pred)
                Recall_LR = accuracy_score(true, pred)
                accuracy_list.append(Accuracy_LR)
                
                print("Accuracy: " + str(Accuracy_LR))
                print("F1 score: " + str(F1_LR))
                print("Recall score: " + str(Recall_LR))
                print("Precision score: " + str(Precision_LR))

# Find the maxmium average accuracy for each combination of hyperparameters
mean_accuracy_list=[]
paramaters_combinition=[]
combinition=[]
for i in range(len(parameters_list)):
    if i < hidden_layer_number* len(param_dist['alpha'])*len(param_dist['activition']):
        for j in  range(len(parameters_list)):
            if parameters_list[i]==parameters_list[j]:
                combinition.append(j)

        accuracy_combinition=[]
        for k in combinition:
            accuracy_combinition.append(accuracy_list[k])
        
        mean_accuracy=np.mean(accuracy_combinition)
        mean_accuracy_list.append(mean_accuracy)
        paramaters_combinition.append(parameters_list[i])

hidden_layer=paramaters_combinition[mean_accuracy_list.index(max(mean_accuracy_list))][0]
alpha=paramaters_combinition[mean_accuracy_list.index(max(mean_accuracy_list))][1]
activition_layer=paramaters_combinition[mean_accuracy_list.index(max(mean_accuracy_list))][2]
# Out:
# [[604, 638], [607, 256, 634, 195], [457, 76, 207], [617, 332], [272, 252, 478, 411], [249, 606, 517, 83], [400, 523, 608, 392], [429, 283, 154, 529], [150, 348, 572, 460, 121], [297, 347, 209, 53, 212], [640, 77], [341]]
# [0.0019, 0.0071, 0.0025, 0.0012, 0.0095, 0.0093, 0.0033, 0.0043]
# ['ReLU', 'LogSigmoid', 'LeakyReLU', 'Sigmoid']
# ####################
# Fold 1
# ####################
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0019
# activition layer:  ReLU
# ********************
# Training Progress: 1 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.094732  [ 1024/52478]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.597675
#
# Epoch 2
# -------------------------------
# loss: 0.573220  [ 1024/52478]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.551083
#
# Epoch 3
# -------------------------------
# loss: 0.496255  [ 1024/52478]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.526264
#
# Epoch 4
# -------------------------------
# loss: 0.511647  [ 1024/52478]
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.484488
#
# Epoch 5
# -------------------------------
# loss: 0.447116  [ 1024/52478]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.464791
#
# Epoch 6
# -------------------------------
# loss: 0.457155  [ 1024/52478]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.441278
#
# Done!
# Accuracy: 0.8330030487804878
# F1 score: 0.8330030487804878
# Recall score: 0.8330030487804878
# Precision score: 0.8330030487804878
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0019
# activition layer:  LogSigmoid
# ********************
# Training Progress: 2 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.105567  [ 1024/52478]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 0.827652
#
# Epoch 2
# -------------------------------
# loss: 0.819549  [ 1024/52478]
# Test Error:
#  Accuracy: 66.6%, Avg loss: 0.757623
#
# Epoch 3
# -------------------------------
# loss: 0.741633  [ 1024/52478]
# Test Error:
#  Accuracy: 66.8%, Avg loss: 0.772623
#
# Epoch 4
# -------------------------------
# loss: 0.745302  [ 1024/52478]
# Test Error:
#  Accuracy: 69.7%, Avg loss: 0.719035
#
# Epoch 5
# -------------------------------
# loss: 0.677926  [ 1024/52478]
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.708361
#
# Epoch 6
# -------------------------------
# loss: 0.686069  [ 1024/52478]
# Test Error:
#  Accuracy: 71.1%, Avg loss: 0.682100
#
# Done!
# Accuracy: 0.7114329268292683
# F1 score: 0.7114329268292683
# Recall score: 0.7114329268292683
# Precision score: 0.7114329268292683
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0019
# activition layer:  LeakyReLU
# ********************
# Training Progress: 3 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.117043  [ 1024/52478]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.603527
#
# Epoch 2
# -------------------------------
# loss: 0.594413  [ 1024/52478]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.567871
#
# Epoch 3
# -------------------------------
# loss: 0.551013  [ 1024/52478]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.493119
#
# Epoch 4
# -------------------------------
# loss: 0.473594  [ 1024/52478]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.449725
#
# Epoch 5
# -------------------------------
# loss: 0.409061  [ 1024/52478]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.442705
#
# Epoch 6
# -------------------------------
# loss: 0.436959  [ 1024/52478]
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.433782
#
# Done!
# Accuracy: 0.8358993902439025
# F1 score: 0.8358993902439025
# Recall score: 0.8358993902439025
# Precision score: 0.8358993902439025
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0019
# activition layer:  Sigmoid
# ********************
# Training Progress: 4 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.152720  [ 1024/52478]
# Test Error:
#  Accuracy: 63.2%, Avg loss: 0.828095
#
# Epoch 2
# -------------------------------
# loss: 0.805714  [ 1024/52478]
# Test Error:
#  Accuracy: 60.3%, Avg loss: 0.817892
#
# Epoch 3
# -------------------------------
# loss: 0.801471  [ 1024/52478]
# Test Error:
#  Accuracy: 57.9%, Avg loss: 0.825790
#
# Epoch 4
# -------------------------------
# loss: 0.837253  [ 1024/52478]
# Test Error:
#  Accuracy: 61.6%, Avg loss: 0.803554
#
# Epoch 5
# -------------------------------
# loss: 0.801097  [ 1024/52478]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 0.826793
#
# Epoch 6
# -------------------------------
# loss: 0.809445  [ 1024/52478]
# Test Error:
#  Accuracy: 64.3%, Avg loss: 0.799523
#
# Done!
# Accuracy: 0.6429115853658537
# F1 score: 0.6429115853658537
# Recall score: 0.6429115853658537
# Precision score: 0.6429115853658537
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0071
# activition layer:  ReLU
# ********************
# Training Progress: 5 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.097838  [ 1024/52478]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.653383
#
# Epoch 2
# -------------------------------
# loss: 0.605496  [ 1024/52478]
# Test Error:
#  Accuracy: 74.4%, Avg loss: 0.605051
#
# Epoch 3
# -------------------------------
# loss: 0.573011  [ 1024/52478]
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.580400
#
# Epoch 4
# -------------------------------
# loss: 0.533469  [ 1024/52478]
# Test Error:
#  Accuracy: 76.1%, Avg loss: 0.574137
#
# Epoch 5
# -------------------------------
# loss: 0.550603  [ 1024/52478]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.533307
#
# Epoch 6
# -------------------------------
# loss: 0.481646  [ 1024/52478]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.518236
#
# Done!
# Accuracy: 0.7977134146341464
# F1 score: 0.7977134146341464
# Recall score: 0.7977134146341464
# Precision score: 0.7977134146341464
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0071
# activition layer:  LogSigmoid
# ********************
# Training Progress: 6 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.210336  [ 1024/52478]
# Test Error:
#  Accuracy: 63.5%, Avg loss: 0.799369
#
# Epoch 2
# -------------------------------
# loss: 0.823981  [ 1024/52478]
# Test Error:
#  Accuracy: 63.8%, Avg loss: 0.748995
#
# Epoch 3
# -------------------------------
# loss: 0.753894  [ 1024/52478]
# Test Error:
#  Accuracy: 59.4%, Avg loss: 0.813712
#
# Epoch 4
# -------------------------------
# loss: 0.831574  [ 1024/52478]
# Test Error:
#  Accuracy: 68.5%, Avg loss: 0.710938
#
# Epoch 5
# -------------------------------
# loss: 0.705404  [ 1024/52478]
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.718647
#
# Epoch 6
# -------------------------------
# loss: 0.694101  [ 1024/52478]
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.705591
#
# Done!
# Accuracy: 0.7004573170731707
# F1 score: 0.7004573170731707
# Recall score: 0.7004573170731707
# Precision score: 0.7004573170731707
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0071
# activition layer:  LeakyReLU
# ********************
# Training Progress: 7 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.104155  [ 1024/52478]
# Test Error:
#  Accuracy: 73.7%, Avg loss: 0.619544
#
# Epoch 2
# -------------------------------
# loss: 0.614109  [ 1024/52478]
# Test Error:
#  Accuracy: 75.8%, Avg loss: 0.583029
#
# Epoch 3
# -------------------------------
# loss: 0.550009  [ 1024/52478]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.541735
#
# Epoch 4
# -------------------------------
# loss: 0.521320  [ 1024/52478]
# Test Error:
#  Accuracy: 71.4%, Avg loss: 0.648601
#
# Epoch 5
# -------------------------------
# loss: 0.608403  [ 1024/52478]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.519242
#
# Epoch 6
# -------------------------------
# loss: 0.482005  [ 1024/52478]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.490272
#
# Done!
# Accuracy: 0.8092987804878049
# F1 score: 0.8092987804878049
# Recall score: 0.8092987804878049
# Precision score: 0.8092987804878049
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0071
# activition layer:  Sigmoid
# ********************
# Training Progress: 8 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.124658  [ 1024/52478]
# Test Error:
#  Accuracy: 57.9%, Avg loss: 0.942596
#
# Epoch 2
# -------------------------------
# loss: 0.954307  [ 1024/52478]
# Test Error:
#  Accuracy: 56.3%, Avg loss: 0.915992
#
# Epoch 3
# -------------------------------
# loss: 0.918103  [ 1024/52478]
# Test Error:
#  Accuracy: 62.6%, Avg loss: 0.840224
#
# Epoch 4
# -------------------------------
# loss: 0.813331  [ 1024/52478]
# Test Error:
#  Accuracy: 62.3%, Avg loss: 0.828811
#
# Epoch 5
# -------------------------------
# loss: 0.818787  [ 1024/52478]
# Test Error:
#  Accuracy: 63.3%, Avg loss: 0.811000
#
# Epoch 6
# -------------------------------
# loss: 0.802884  [ 1024/52478]
# Test Error:
#  Accuracy: 61.9%, Avg loss: 0.809797
#
# Done!
# Accuracy: 0.61875
# F1 score: 0.61875
# Recall score: 0.61875
# Precision score: 0.61875
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0025
# activition layer:  ReLU
# ********************
# Training Progress: 9 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.089901  [ 1024/52478]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.608820
#
# Epoch 2
# -------------------------------
# loss: 0.620684  [ 1024/52478]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.534851
#
# Epoch 3
# -------------------------------
# loss: 0.494280  [ 1024/52478]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.553567
#
# Epoch 4
# -------------------------------
# loss: 0.521775  [ 1024/52478]
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.483066
#
# Epoch 5
# -------------------------------
# loss: 0.471242  [ 1024/52478]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.455629
#
# Epoch 6
# -------------------------------
# loss: 0.410803  [ 1024/52478]
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.483925
#
# Done!
# Accuracy: 0.8158536585365853
# F1 score: 0.8158536585365853
# Recall score: 0.8158536585365853
# Precision score: 0.8158536585365853
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0025
# activition layer:  LogSigmoid
# ********************
# Training Progress: 10 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.101153  [ 1024/52478]
# Test Error:
#  Accuracy: 61.1%, Avg loss: 0.812660
#
# Epoch 2
# -------------------------------
# loss: 0.801834  [ 1024/52478]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.758462
#
# Epoch 3
# -------------------------------
# loss: 0.757279  [ 1024/52478]
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.727034
#
# Epoch 4
# -------------------------------
# loss: 0.685467  [ 1024/52478]
# Test Error:
#  Accuracy: 67.9%, Avg loss: 0.726232
#
# Epoch 5
# -------------------------------
# loss: 0.707847  [ 1024/52478]
# Test Error:
#  Accuracy: 68.5%, Avg loss: 0.695319
#
# Epoch 6
# -------------------------------
# loss: 0.674603  [ 1024/52478]
# Test Error:
#  Accuracy: 57.1%, Avg loss: 0.969114
#
# Done!
# Accuracy: 0.5706554878048781
# F1 score: 0.5706554878048781
# Recall score: 0.5706554878048781
# Precision score: 0.5706554878048781
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0025
# activition layer:  LeakyReLU
# ********************
# Training Progress: 11 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.109154  [ 1024/52478]
# Test Error:
#  Accuracy: 75.8%, Avg loss: 0.602924
#
# Epoch 2
# -------------------------------
# loss: 0.583604  [ 1024/52478]
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.571063
#
# Epoch 3
# -------------------------------
# loss: 0.540949  [ 1024/52478]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.510999
#
# Epoch 4
# -------------------------------
# loss: 0.452229  [ 1024/52478]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.473558
#
# Epoch 5
# -------------------------------
# loss: 0.433025  [ 1024/52478]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.453096
#
# Epoch 6
# -------------------------------
# loss: 0.463144  [ 1024/52478]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.424117
#
# Done!
# Accuracy: 0.8410060975609757
# F1 score: 0.8410060975609757
# Recall score: 0.8410060975609757
# Precision score: 0.8410060975609757
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0025
# activition layer:  Sigmoid
# ********************
# Training Progress: 12 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.110221  [ 1024/52478]
# Test Error:
#  Accuracy: 61.1%, Avg loss: 0.844934
#
# Epoch 2
# -------------------------------
# loss: 0.826129  [ 1024/52478]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 0.834792
#
# Epoch 3
# -------------------------------
# loss: 0.883920  [ 1024/52478]
# Test Error:
#  Accuracy: 62.7%, Avg loss: 0.821869
#
# Epoch 4
# -------------------------------
# loss: 0.829020  [ 1024/52478]
# Test Error:
#  Accuracy: 64.8%, Avg loss: 0.792218
#
# Epoch 5
# -------------------------------
# loss: 0.783793  [ 1024/52478]
# Test Error:
#  Accuracy: 64.5%, Avg loss: 0.783371
#
# Epoch 6
# -------------------------------
# loss: 0.760852  [ 1024/52478]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.790522
#
# Done!
# Accuracy: 0.6594512195121951
# F1 score: 0.6594512195121951
# Recall score: 0.6594512195121951
# Precision score: 0.6594512195121951
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0012
# activition layer:  ReLU
# ********************
# Training Progress: 13 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.110105  [ 1024/52478]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.607730
#
# Epoch 2
# -------------------------------
# loss: 0.618277  [ 1024/52478]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.544950
#
# Epoch 3
# -------------------------------
# loss: 0.524051  [ 1024/52478]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.484231
#
# Epoch 4
# -------------------------------
# loss: 0.435809  [ 1024/52478]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.457718
#
# Epoch 5
# -------------------------------
# loss: 0.436039  [ 1024/52478]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.473407
#
# Epoch 6
# -------------------------------
# loss: 0.431323  [ 1024/52478]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.415348
#
# Done!
# Accuracy: 0.84375
# F1 score: 0.84375
# Recall score: 0.84375
# Precision score: 0.84375
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0012
# activition layer:  LogSigmoid
# ********************
# Training Progress: 14 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.103478  [ 1024/52478]
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.777990
#
# Epoch 2
# -------------------------------
# loss: 0.742913  [ 1024/52478]
# Test Error:
#  Accuracy: 67.2%, Avg loss: 0.742909
#
# Epoch 3
# -------------------------------
# loss: 0.773222  [ 1024/52478]
# Test Error:
#  Accuracy: 67.0%, Avg loss: 0.728189
#
# Epoch 4
# -------------------------------
# loss: 0.715485  [ 1024/52478]
# Test Error:
#  Accuracy: 68.3%, Avg loss: 0.725259
#
# Epoch 5
# -------------------------------
# loss: 0.735149  [ 1024/52478]
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.693992
#
# Epoch 6
# -------------------------------
# loss: 0.683080  [ 1024/52478]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.730666
#
# Done!
# Accuracy: 0.6801829268292683
# F1 score: 0.6801829268292683
# Recall score: 0.6801829268292683
# Precision score: 0.6801829268292683
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0012
# activition layer:  LeakyReLU
# ********************
# Training Progress: 15 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.100922  [ 1024/52478]
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.592122
#
# Epoch 2
# -------------------------------
# loss: 0.576195  [ 1024/52478]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.529442
#
# Epoch 3
# -------------------------------
# loss: 0.516562  [ 1024/52478]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.487938
#
# Epoch 4
# -------------------------------
# loss: 0.436106  [ 1024/52478]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.513342
#
# Epoch 5
# -------------------------------
# loss: 0.485493  [ 1024/52478]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.453828
#
# Epoch 6
# -------------------------------
# loss: 0.442971  [ 1024/52478]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.421362
#
# Done!
# Accuracy: 0.8432926829268292
# F1 score: 0.8432926829268292
# Recall score: 0.8432926829268292
# Precision score: 0.8432926829268292
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0012
# activition layer:  Sigmoid
# ********************
# Training Progress: 16 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.133956  [ 1024/52478]
# Test Error:
#  Accuracy: 62.3%, Avg loss: 0.839647
#
# Epoch 2
# -------------------------------
# loss: 0.838721  [ 1024/52478]
# Test Error:
#  Accuracy: 63.5%, Avg loss: 0.824157
#
# Epoch 3
# -------------------------------
# loss: 0.792415  [ 1024/52478]
# Test Error:
#  Accuracy: 64.3%, Avg loss: 0.797344
#
# Epoch 4
# -------------------------------
# loss: 0.778620  [ 1024/52478]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 0.812473
#
# Epoch 5
# -------------------------------
# loss: 0.835315  [ 1024/52478]
# Test Error:
#  Accuracy: 61.8%, Avg loss: 0.799790
#
# Epoch 6
# -------------------------------
# loss: 0.825979  [ 1024/52478]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.783606
#
# Done!
# Accuracy: 0.6580792682926829
# F1 score: 0.6580792682926829
# Recall score: 0.6580792682926829
# Precision score: 0.6580792682926829
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0095
# activition layer:  ReLU
# ********************
# Training Progress: 17 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.096560  [ 1024/52478]
# Test Error:
#  Accuracy: 72.9%, Avg loss: 0.645521
#
# Epoch 2
# -------------------------------
# loss: 0.640478  [ 1024/52478]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.617250
#
# Epoch 3
# -------------------------------
# loss: 0.604336  [ 1024/52478]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.566050
#
# Epoch 4
# -------------------------------
# loss: 0.529565  [ 1024/52478]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.568142
#
# Epoch 5
# -------------------------------
# loss: 0.542532  [ 1024/52478]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.529008
#
# Epoch 6
# -------------------------------
# loss: 0.519703  [ 1024/52478]
# Test Error:
#  Accuracy: 80.4%, Avg loss: 0.506465
#
# Done!
# Accuracy: 0.8044969512195121
# F1 score: 0.8044969512195121
# Recall score: 0.8044969512195121
# Precision score: 0.8044969512195121
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0095
# activition layer:  LogSigmoid
# ********************
# Training Progress: 18 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.110586  [ 1024/52478]
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.789573
#
# Epoch 2
# -------------------------------
# loss: 0.766707  [ 1024/52478]
# Test Error:
#  Accuracy: 61.1%, Avg loss: 0.865579
#
# Epoch 3
# -------------------------------
# loss: 0.890282  [ 1024/52478]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.785045
#
# Epoch 4
# -------------------------------
# loss: 0.788844  [ 1024/52478]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.732157
#
# Epoch 5
# -------------------------------
# loss: 0.743332  [ 1024/52478]
# Test Error:
#  Accuracy: 67.3%, Avg loss: 0.755908
#
# Epoch 6
# -------------------------------
# loss: 0.770413  [ 1024/52478]
# Test Error:
#  Accuracy: 70.5%, Avg loss: 0.685924
#
# Done!
# Accuracy: 0.7054878048780487
# F1 score: 0.7054878048780487
# Recall score: 0.7054878048780487
# Precision score: 0.7054878048780487
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0095
# activition layer:  LeakyReLU
# ********************
# Training Progress: 19 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.113943  [ 1024/52478]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.639357
#
# Epoch 2
# -------------------------------
# loss: 0.638123  [ 1024/52478]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.604928
#
# Epoch 3
# -------------------------------
# loss: 0.614718  [ 1024/52478]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.560613
#
# Epoch 4
# -------------------------------
# loss: 0.532671  [ 1024/52478]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.551071
#
# Epoch 5
# -------------------------------
# loss: 0.539658  [ 1024/52478]
# Test Error:
#  Accuracy: 72.9%, Avg loss: 0.642842
#
# Epoch 6
# -------------------------------
# loss: 0.603220  [ 1024/52478]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.564488
#
# Done!
# Accuracy: 0.7761432926829268
# F1 score: 0.7761432926829268
# Recall score: 0.7761432926829268
# Precision score: 0.7761432926829268
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0095
# activition layer:  Sigmoid
# ********************
# Training Progress: 20 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.108805  [ 1024/52478]
# Test Error:
#  Accuracy: 52.5%, Avg loss: 0.982108
#
# Epoch 2
# -------------------------------
# loss: 0.987698  [ 1024/52478]
# Test Error:
#  Accuracy: 55.0%, Avg loss: 0.961537
#
# Epoch 3
# -------------------------------
# loss: 0.937920  [ 1024/52478]
# Test Error:
#  Accuracy: 57.9%, Avg loss: 0.871597
#
# Epoch 4
# -------------------------------
# loss: 0.865846  [ 1024/52478]
# Test Error:
#  Accuracy: 58.9%, Avg loss: 0.860249
#
# Epoch 5
# -------------------------------
# loss: 0.864725  [ 1024/52478]
# Test Error:
#  Accuracy: 49.4%, Avg loss: 0.954255
#
# Epoch 6
# -------------------------------
# loss: 0.950065  [ 1024/52478]
# Test Error:
#  Accuracy: 54.6%, Avg loss: 0.898095
#
# Done!
# Accuracy: 0.545655487804878
# F1 score: 0.545655487804878
# Recall score: 0.545655487804878
# Precision score: 0.545655487804878
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0093
# activition layer:  ReLU
# ********************
# Training Progress: 21 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.109946  [ 1024/52478]
# Test Error:
#  Accuracy: 72.3%, Avg loss: 0.648967
#
# Epoch 2
# -------------------------------
# loss: 0.637993  [ 1024/52478]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.603189
#
# Epoch 3
# -------------------------------
# loss: 0.581489  [ 1024/52478]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.583236
#
# Epoch 4
# -------------------------------
# loss: 0.575179  [ 1024/52478]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.555547
#
# Epoch 5
# -------------------------------
# loss: 0.525728  [ 1024/52478]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.531715
#
# Epoch 6
# -------------------------------
# loss: 0.552981  [ 1024/52478]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.552662
#
# Done!
# Accuracy: 0.7887195121951219
# F1 score: 0.7887195121951219
# Recall score: 0.7887195121951219
# Precision score: 0.7887195121951219
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0093
# activition layer:  LogSigmoid
# ********************
# Training Progress: 22 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.135919  [ 1024/52478]
# Test Error:
#  Accuracy: 62.8%, Avg loss: 0.798876
#
# Epoch 2
# -------------------------------
# loss: 0.789152  [ 1024/52478]
# Test Error:
#  Accuracy: 60.2%, Avg loss: 0.849030
#
# Epoch 3
# -------------------------------
# loss: 0.840693  [ 1024/52478]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.858799
#
# Epoch 4
# -------------------------------
# loss: 0.803261  [ 1024/52478]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.766602
#
# Epoch 5
# -------------------------------
# loss: 0.776126  [ 1024/52478]
# Test Error:
#  Accuracy: 70.4%, Avg loss: 0.682468
#
# Epoch 6
# -------------------------------
# loss: 0.688988  [ 1024/52478]
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.696159
#
# Done!
# Accuracy: 0.6964176829268293
# F1 score: 0.6964176829268293
# Recall score: 0.6964176829268293
# Precision score: 0.6964176829268293
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0093
# activition layer:  LeakyReLU
# ********************
# Training Progress: 23 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.111621  [ 1024/52478]
# Test Error:
#  Accuracy: 71.8%, Avg loss: 0.657765
#
# Epoch 2
# -------------------------------
# loss: 0.655878  [ 1024/52478]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.596473
#
# Epoch 3
# -------------------------------
# loss: 0.615851  [ 1024/52478]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.596612
#
# Epoch 4
# -------------------------------
# loss: 0.642042  [ 1024/52478]
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.587445
#
# Epoch 5
# -------------------------------
# loss: 0.548706  [ 1024/52478]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.567834
#
# Epoch 6
# -------------------------------
# loss: 0.534034  [ 1024/52478]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.532701
#
# Done!
# Accuracy: 0.7910823170731708
# F1 score: 0.7910823170731708
# Recall score: 0.7910823170731708
# Precision score: 0.7910823170731708
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0093
# activition layer:  Sigmoid
# ********************
# Training Progress: 24 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.187988  [ 1024/52478]
# Test Error:
#  Accuracy: 55.3%, Avg loss: 0.890271
#
# Epoch 2
# -------------------------------
# loss: 0.905166  [ 1024/52478]
# Test Error:
#  Accuracy: 55.3%, Avg loss: 0.882273
#
# Epoch 3
# -------------------------------
# loss: 0.865734  [ 1024/52478]
# Test Error:
#  Accuracy: 59.9%, Avg loss: 0.848023
#
# Epoch 4
# -------------------------------
# loss: 0.848223  [ 1024/52478]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.836304
#
# Epoch 5
# -------------------------------
# loss: 0.830931  [ 1024/52478]
# Test Error:
#  Accuracy: 63.2%, Avg loss: 0.846206
#
# Epoch 6
# -------------------------------
# loss: 0.833457  [ 1024/52478]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.818640
#
# Done!
# Accuracy: 0.6464939024390244
# F1 score: 0.6464939024390244
# Recall score: 0.6464939024390244
# Precision score: 0.6464939024390244
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0033
# activition layer:  ReLU
# ********************
# Training Progress: 25 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.088736  [ 1024/52478]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.629887
#
# Epoch 2
# -------------------------------
# loss: 0.629931  [ 1024/52478]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.536067
#
# Epoch 3
# -------------------------------
# loss: 0.542387  [ 1024/52478]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.529383
#
# Epoch 4
# -------------------------------
# loss: 0.460240  [ 1024/52478]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.505594
#
# Epoch 5
# -------------------------------
# loss: 0.479725  [ 1024/52478]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.472588
#
# Epoch 6
# -------------------------------
# loss: 0.457521  [ 1024/52478]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.449199
#
# Done!
# Accuracy: 0.8266006097560976
# F1 score: 0.8266006097560976
# Recall score: 0.8266006097560976
# Precision score: 0.8266006097560976
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0033
# activition layer:  LogSigmoid
# ********************
# Training Progress: 26 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.196050  [ 1024/52478]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 0.815969
#
# Epoch 2
# -------------------------------
# loss: 0.821310  [ 1024/52478]
# Test Error:
#  Accuracy: 63.1%, Avg loss: 0.776852
#
# Epoch 3
# -------------------------------
# loss: 0.779036  [ 1024/52478]
# Test Error:
#  Accuracy: 66.8%, Avg loss: 0.751445
#
# Epoch 4
# -------------------------------
# loss: 0.733804  [ 1024/52478]
# Test Error:
#  Accuracy: 64.4%, Avg loss: 0.762976
#
# Epoch 5
# -------------------------------
# loss: 0.764705  [ 1024/52478]
# Test Error:
#  Accuracy: 67.3%, Avg loss: 0.704321
#
# Epoch 6
# -------------------------------
# loss: 0.682902  [ 1024/52478]
# Test Error:
#  Accuracy: 69.9%, Avg loss: 0.688117
#
# Done!
# Accuracy: 0.698704268292683
# F1 score: 0.698704268292683
# Recall score: 0.698704268292683
# Precision score: 0.698704268292683
# ********************
# hidden size:  [604, 638]
# learning rate:  0.0033
# activition layer:  LeakyReLU
# ********************
# Training Progress: 27 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=604, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=604, out_features=638, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=638, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.092123  [ 1024/52478]
# Test Error:
#  Accuracy: 75.1%, Avg loss: 0.596567
#
# Epoch 2
# -------------------------------
# loss: 0.553111  [ 1024/52478]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.562203
#
# Epoch 3
# -------------------------------
# loss: 0.535875  [ 1024/52478]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.526649
#
# Epoch 4
# -------------------------------
# loss: 0.504914  [ 1024/52478]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.618312
#
# Epoch 5
# -------------------------------
# loss: 0.574657  [ 1024/52478]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.465329
#
# Epoch 6
# -------------------------------
# loss: 0.446132  [ 1024/52478]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.501799
#
# ...
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.099317  [ 1024/52478]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.599757
#
# Epoch 2
# -------------------------------
# loss: 0.571952  [ 1024/52478]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.568291
#
# Epoch 3
# -------------------------------
# loss: 0.534685  [ 1024/52478]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.496916
#
# Epoch 4
# -------------------------------
# loss: 0.462696  [ 1024/52478]
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.493379
#
# Epoch 5
# -------------------------------
# loss: 0.469181  [ 1024/52478]
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.493346
#
# Epoch 6
# -------------------------------
# loss: 0.466437  [ 1024/52478]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.442321
#
# Done!
# Accuracy: 0.833765243902439
# F1 score: 0.833765243902439
# Recall score: 0.833765243902439
# Precision score: 0.833765243902439
# ********************
# hidden size:  [272, 252, 478, 411]
# learning rate:  0.0033
# activition layer:  Sigmoid
# ********************
# Training Progress: 156 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.154031  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.099845
#
# Epoch 2
# -------------------------------
# loss: 1.100435  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.120819
#
# Epoch 3
# -------------------------------
# loss: 1.122018  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.101981
#
# Epoch 4
# -------------------------------
# loss: 1.098377  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.117806
#
# Epoch 5
# -------------------------------
# loss: 1.111547  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.098329
#
# Epoch 6
# -------------------------------
# loss: 1.098677  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.098333
#
# Done!
# Accuracy: 0.3362042682926829
# F1 score: 0.3362042682926829
# Recall score: 0.3362042682926829
# Precision score: 0.3362042682926829
# ********************
# hidden size:  [272, 252, 478, 411]
# learning rate:  0.0043
# activition layer:  ReLU
# ********************
# Training Progress: 157 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.099002  [ 1024/52478]
# Test Error:
#  Accuracy: 73.6%, Avg loss: 0.630923
#
# Epoch 2
# -------------------------------
# loss: 0.644588  [ 1024/52478]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.538209
#
# Epoch 3
# -------------------------------
# loss: 0.510832  [ 1024/52478]
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.532141
#
# Epoch 4
# -------------------------------
# loss: 0.514857  [ 1024/52478]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.480344
#
# Epoch 5
# -------------------------------
# loss: 0.457577  [ 1024/52478]
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.466845
#
# Epoch 6
# -------------------------------
# loss: 0.461086  [ 1024/52478]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.455612
#
# Done!
# Accuracy: 0.8229420731707318
# F1 score: 0.8229420731707318
# Recall score: 0.8229420731707318
# Precision score: 0.8229420731707318
# ********************
# hidden size:  [272, 252, 478, 411]
# learning rate:  0.0043
# activition layer:  LogSigmoid
# ********************
# Training Progress: 158 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): LogSigmoid()
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): LogSigmoid()
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): LogSigmoid()
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): LogSigmoid()
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.205002  [ 1024/52478]
# Test Error:
#  Accuracy: 58.8%, Avg loss: 0.902128
#
# Epoch 2
# -------------------------------
# loss: 0.894423  [ 1024/52478]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.793009
#
# Epoch 3
# -------------------------------
# loss: 0.813574  [ 1024/52478]
# Test Error:
#  Accuracy: 61.5%, Avg loss: 0.785715
#
# Epoch 4
# -------------------------------
# loss: 0.796178  [ 1024/52478]
# Test Error:
#  Accuracy: 62.7%, Avg loss: 0.779112
#
# Epoch 5
# -------------------------------
# loss: 0.763960  [ 1024/52478]
# Test Error:
#  Accuracy: 61.6%, Avg loss: 0.775323
#
# Epoch 6
# -------------------------------
# loss: 0.779969  [ 1024/52478]
# Test Error:
#  Accuracy: 67.1%, Avg loss: 0.760114
#
# Done!
# Accuracy: 0.6708079268292683
# F1 score: 0.6708079268292683
# Recall score: 0.6708079268292683
# Precision score: 0.6708079268292683
# ********************
# hidden size:  [272, 252, 478, 411]
# learning rate:  0.0043
# activition layer:  LeakyReLU
# ********************
# Training Progress: 159 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.098502  [ 1024/52478]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.608599
#
# Epoch 2
# -------------------------------
# loss: 0.602059  [ 1024/52478]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.542635
#
# Epoch 3
# -------------------------------
# loss: 0.514676  [ 1024/52478]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.553766
#
# Epoch 4
# -------------------------------
# loss: 0.528579  [ 1024/52478]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.483464
#
# Epoch 5
# -------------------------------
# loss: 0.455423  [ 1024/52478]
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.477685
#
# Epoch 6
# -------------------------------
# loss: 0.488690  [ 1024/52478]
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.454780
#
# Done!
# Accuracy: 0.8308689024390243
# F1 score: 0.8308689024390243
# Recall score: 0.8308689024390243
# Precision score: 0.8308689024390243
# ********************
# hidden size:  [272, 252, 478, 411]
# learning rate:  0.0043
# activition layer:  Sigmoid
# ********************
# Training Progress: 160 / 1920
# ********************
# DNN_rs(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120, out_features=272, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=272, out_features=252, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=252, out_features=478, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=478, out_features=411, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=411, out_features=3, bias=True)
#   )
# )
# tensor([[-0.1631, -0.2355, -0.6114,  ..., -0.1141,  0.6617,  0.2227],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.9908, -1.0163, -0.3997],
#         [ 0.2471,  2.4561,  2.2423,  ...,  0.0083,  0.8434, -0.6080],
#         ...,
#         [-1.0014, -0.9091, -1.1114,  ...,  0.5186,  0.8543, -0.4312],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.0785, -0.6884, -0.1302],
#         [-0.8323, -0.9774, -0.7326,  ..., -0.3202, -0.4927,  0.2046]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.134250  [ 1024/52478]
# Test Error:
#  Accuracy: 32.8%, Avg loss: 1.106624
#
# Epoch 2
# -------------------------------
# loss: 1.105211  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.101131
#
# Epoch 3
# -------------------------------
# loss: 1.103575  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.108819
#
# Epoch 4
# -------------------------------
# loss: 1.105256  [ 1024/52478]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.104139
#
# Epoch 5
# -------------------------------
# loss: 1.104328  [ 1024/52478]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Hong-01\EE4C12-Epileptic-Seizure-Detection-using-EEG\SZD.ipynb 单元格 68 line 7
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=74'>75</a> for t in range(epochs):
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=75'>76</a>     print(f"Epoch {t+1}\n-------------------------------")
# ---> <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=76'>77</a>     train(train_dataloader, model_rs, loss_fn, optimizer_rs)
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=77'>78</a>     test(validation_dataloader, model_rs, loss_fn)
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=78'>79</a> print("Done!")
#
# Hong-01\EE4C12-Epileptic-Seizure-Detection-using-EEG\SZD.ipynb 单元格 68 line 5
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=2'>3</a> size = len(dataloader.dataset)
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=3'>4</a> model.train()
# ----> <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=4'>5</a> for batch, (X, y) in enumerate(dataloader):
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=5'>6</a>     X, y = X.to(device), y.to(device)
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=7'>8</a>     # Compute prediction error
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Hong-01\EE4C12-Epileptic-Seizure-Detection-using-EEG\SZD.ipynb 单元格 68 line 1
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=11'>12</a> def __len__(self):
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=12'>13</a>     return self.X.shape[0]
# ---> <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=14'>15</a> def __getitem__(self, idx):
#      <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y124sdnNjb2RlLXZmcw%3D%3D?line=15'>16</a>     return self.X[idx], self.y[idx]
#
# KeyboardInterrupt:

# %% [markdown]
# #### 3.4.3 Model validation result

# %%
#Show the coonfusion matrix for the best hyperparameters
print("#"*20)
print("Confusion matrix for the best hyperparameters in each fold")
print("#"*20)
print("hidden size: ", hidden_layer)
print("learning rate: ", alpha)
print("activition layer: ", activition_layer)

optimizer_rs.lr = alpha
model_rs = DNN_rs(input_size, hidden_layer, output_size, activition_layer).to(device)
print(model_rs)

for i in range(len(X_k_train_list)):

    print("#"*20)
    print("Fold " + str(i+1))
    batch_size = 1024
    trainset_gpu = Data_tensor(X_k_train_list[i], y_k_train_list[i])
    valset_gpu = Data_tensor(X_k_val_list[i], y_k_val_list[i])
    train_dataloader = DataLoader(trainset_gpu, batch_size=batch_size, shuffle=True)
    validation_dataloader = DataLoader(valset_gpu, batch_size=batch_size, shuffle=False)
    epochs = 10
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")
        train(train_dataloader, model_rs, loss_fn, optimizer_rs)
        test(validation_dataloader, model_rs, loss_fn)
    print("Done!")

    model_rs.eval()
    pred = model_rs(validation_dataloader.dataset[:][0]).detach().cpu().max(axis=1).indices.numpy()
    true = validation_dataloader.dataset[:][1].cpu().numpy()

    #Performance metrics
    Accuracy_LR = accuracy_score(true, pred)
    F1_LR = accuracy_score(true, pred)
    Precision_LR = accuracy_score(true, pred)
    Recall_LR = accuracy_score(true, pred)

    print("Accuracy: " + str(Accuracy_LR))
    print("F1 score: " + str(F1_LR))
    print("Recall score: " + str(Recall_LR))
    print("Precision score: " + str(Precision_LR))


    print("one value in validation set: ",sum(true==2))
    print("zero value in validation set: ",sum(true==1))
    print("negative one value in validation set: ",sum(true==0))

    cm_2c = confusion_matrix(true, pred)
    cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()

    plt.show()
    print("#"*20)


#Display the best hyperparameters and the corresponding average accuracy
print("#"*20)
print("The best hidden layer size is", hidden_layer)
print("The best learning rate is", alpha)
print("The best activition layer is", activition_layer)
print("The best average accuracy is", max(mean_accuracy_list))
print("#"*20)
# Out:
# ####################
# Confusion matrix for the best hyperparameters in each fold
# ####################
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Hong-01\EE4C12-Epileptic-Seizure-Detection-using-EEG\SZD.ipynb 单元格 71 line 5
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y130sdnNjb2RlLXZmcw%3D%3D?line=2'>3</a> print("Confusion matrix for the best hyperparameters in each fold")
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y130sdnNjb2RlLXZmcw%3D%3D?line=3'>4</a> print("#"*20)
# ----> <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y130sdnNjb2RlLXZmcw%3D%3D?line=4'>5</a> print("hidden size: ", hidden_layer)
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y130sdnNjb2RlLXZmcw%3D%3D?line=5'>6</a> print("learning rate: ", alpha)
#       <a href='vscode-notebook-cell://github/Hong-01/EE4C12-Epileptic-Seizure-Detection-using-EEG/SZD.ipynb#Y130sdnNjb2RlLXZmcw%3D%3D?line=6'>7</a> print("activition layer: ", activition_layer)
#
# NameError: name 'hidden_layer' is not defined

# %% [markdown]
# #### 3.4.4 Model evaluation

# %%
#evaluation on test set
optimizer_rs.lr = alpha
model_rs = DNN_rs(input_size, hidden_layer, output_size, activition_layer).to(device)

testset_gpu = Data_tensor(X_test_scaled, y_test)
test_dataloader = DataLoader(testset_gpu, batch_size=batch_size, shuffle=False)
model_rs.eval()
pred = model_rs(test_dataloader.dataset[:][0]).detach().cpu().max(axis=1).indices.numpy()
true = test_dataloader.dataset[:][1].cpu().numpy()

#Performance metrics
Accuracy_LR = accuracy_score(true, pred)
F1_LR = accuracy_score(true, pred)

Precision_LR = accuracy_score(true, pred)
Recall_LR = accuracy_score(true, pred)
print("Accuracy: " + str(Accuracy_LR))
print("F1 score: " + str(F1_LR))
print("Recall score: " + str(Recall_LR))
print("Precision score: " + str(Precision_LR))

print("zero value in test set: ",sum(true==1))
cm_2c = confusion_matrix(true, pred)
cm_display_2c = ConfusionMatrixDisplay(cm_2c, display_labels=classification_lable).plot()
plt.show()

# %% [markdown]
# #### 3.4.5 Model summary

# %%
#DNN summary
print("-----------------DNN Summary-----------------")
print("Best hidden layer size:", hidden_layer)
print("Best learning rate:", alpha)
print("Best activition layer:", activition_layer)
print("Mean average accuracy in validation set with best parameter:", np.mean(mean_accuracy_list))
print("Accuracy in test set with best parameter: " + str(Accuracy_LR))
print("-------------------------------------------------------------")

# %% [markdown]
# ## 4. Clustering

# %%
patient_id = data.iloc[:, 0].values 
patient_id_unique = np.unique(patient_id)
print(patient_id_unique)
print(len(patient_id_unique))
def pca_process(data,n_components):

    pca =  PCA(n_components=n_components)
    pca.fit(data)
    x_pca =pca.transform(data)
    return x_pca

# %%
x_pca=0
x_pca=pca_process(X,2)
x_pca_patient_list=[0]*len(patient_id_unique)
print(x_pca.shape)
for i in range(len(patient_id_unique)):
    cut_list=[]
    for j in range(len(patient_id)):
        if patient_id[j]==patient_id_unique[i]:
            cut_list=np.append(cut_list,j)
    x_pca_patient_list[i]=x_pca[np.int32(cut_list[0]):np.int32(cut_list[-1]+1)]

# %%
plt.figure(figsize=(15,15))

sca1 = plt.scatter(x_pca_patient_list[0][:,0],x_pca_patient_list[0][:,1],c='r')
sca2 = plt.scatter(x_pca_patient_list[1][:,0],x_pca_patient_list[1][:,1],c='b')
sca3 = plt.scatter(x_pca_patient_list[2][:,0],x_pca_patient_list[2][:,1],c='g')
sca4 = plt.scatter(x_pca_patient_list[3][:,0],x_pca_patient_list[3][:,1],c='y')
sca5 = plt.scatter(x_pca_patient_list[4][:,0],x_pca_patient_list[4][:,1],c='c')
sca6 = plt.scatter(x_pca_patient_list[5][:,0],x_pca_patient_list[5][:,1],c='m')
sca7 = plt.scatter(x_pca_patient_list[6][:,0],x_pca_patient_list[6][:,1],c='k')
sca8 = plt.scatter(x_pca_patient_list[7][:,0],x_pca_patient_list[7][:,1],c='r',marker='P')
sca9 = plt.scatter(x_pca_patient_list[8][:,0],x_pca_patient_list[8][:,1],c='g',marker='P')
sca10 = plt.scatter(x_pca_patient_list[9][:,0],x_pca_patient_list[9][:,1],c='b',marker='P')
sca11 = plt.scatter(x_pca_patient_list[10][:,0],x_pca_patient_list[10][:,1],c='y',marker='P')
sca12 = plt.scatter(x_pca_patient_list[11][:,0],x_pca_patient_list[11][:,1],c='c',marker='P')
sca13 = plt.scatter(x_pca_patient_list[12][:,0],x_pca_patient_list[12][:,1],c='m',marker='P')
sca14 = plt.scatter(x_pca_patient_list[13][:,0],x_pca_patient_list[13][:,1],c='k',marker='P')
sca15 = plt.scatter(x_pca_patient_list[14][:,0],x_pca_patient_list[14][:,1],c='r',marker='s')


plt.xlabel("First principal component")
plt.ylabel("Second principal component")
plt.title("PCA of the EEG data")
plt.legend((sca1,sca2,sca3,sca4,sca5,sca6,sca7,sca8,sca9,sca10,sca11,sca12,sca13,sca14,sca15),patient_id_unique)
plt.show()

# %%
# perform k-means clustering
kmeans = KMeans(n_clusters=15, random_state=0).fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

print(labels)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
plt.figure(figsize=(15,15))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels)
# plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('K-means Clustering')
# plt.legend()
plt.show()

# %%
# # DNN class for normal training hidden sizes are fixed (512,512)
# class DNN(nn.Module):
#     def __init__(self, input_size=512, output_size=10):
#         super().__init__()
#         self.linear_relu_stack = nn.Sequential(
#             nn.Linear(input_size, 512),
#             nn.LeakyReLU(),
#             # nn.SELU(),
#             # nn.Tanh(),
#             nn.Linear(512, 512),
#             nn.LeakyReLU(),
#             # nn.SELU(),
#             # nn.Tanh(),
#             nn.Linear(512, output_size)
#         )

#     def forward(self, x):
#         logits = self.linear_relu_stack(x)
#         return logits

# model = DNN(X_train_scaled.shape[1], 3).to(device)
# print(model)

# optimizer = torch.optim.Adam(model.parameters(),weight_decay=0.005) # Adam optimizer for normal training
# loss_fn = nn.CrossEntropyLoss() # CrossEntropyLoss for multi-classification
# Out:
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# optimizer = torch.optim.Adam(model.parameters(),weight_decay=0.005) # Adam optimizer for normal training

# %%
# # K-fold cross validation for DNN
# train_dataloader_list = []
# val_dataloader_list = []
# accuracy=[]
# X_k_train_list, y_k_train_list, X_k_val_list, y_k_val_list = Kfold_split(X_train_scaled, y_train, Shuffle_state)
# for i in range(len(X_k_train_list)):
#     print("#"*20)
#     print("Fold " + str(i+1))
#     batch_size = 1024
#     trainset_gpu = Data_tensor(X_k_train_list[i], y_k_train_list[i])
#     valset_gpu = Data_tensor(X_k_val_list[i], y_k_val_list[i])
#     train_dataloader = DataLoader(trainset_gpu, batch_size=batch_size, shuffle=True)
#     val_dataloader = DataLoader(valset_gpu, batch_size=batch_size, shuffle=False)
#     epochs =   10
#     print(train_dataloader.dataset[:][0])
#     for t in range(epochs):
#         print(f"Epoch {t+1}\n-------------------------------")
#         train(train_dataloader, model, loss_fn, optimizer)
#         test(val_dataloader, model, loss_fn)
#     print("Done!")
#     print(model)
#     model_rs.eval()
#     pred = model(val_dataloader.dataset[:][0]).detach().cpu().max(axis=1).indices.numpy()
#     # print(pred)
#     true = val_dataloader.dataset[:][1].cpu().numpy()
#     # print(true)
#     #Performance metrics
#     Accuracy_LR = accuracy_score(true, pred)
#     F1_LR = accuracy_score(true, pred)
#     Precision_LR = accuracy_score(true, pred)
#     Recall_LR = accuracy_score(true, pred)
#     accuracy.append(Accuracy_LR)
#     print("Accuracy: " + str(Accuracy_LR))
#     print("F1 score: " + str(F1_LR))
#     print("Recall score: " + str(Recall_LR))
#     print("Precision score: " + str(Precision_LR))
#     print("zero value in validation set: ",sum(true==1))
#     cm_2c = confusion_matrix(true, pred)
#     cm_display_2c = ConfusionMatrixDisplay(cm_2c).plot()
#     plt.show()
#     print("#"*20)
# print("#"*20)

# print("The average accuracy is", np.mean(accuracy))
# print("#"*20)


# testset_gpu = Data_tensor(X_test_scaled, y_test)
# test_dataloader = DataLoader(testset_gpu, batch_size=batch_size, shuffle=False)
# model.eval()
# pred = model(test_dataloader.dataset[:][0]).detach().cpu().max(axis=1).indices.numpy()
# true = test_dataloader.dataset[:][1].cpu().numpy()
# #Performance metrics
# Accuracy_LR = accuracy_score(true, pred)
# F1_LR = accuracy_score(true, pred)

# Precision_LR = accuracy_score(true, pred)
# Recall_LR = accuracy_score(true, pred)
# print("Accuracy: " + str(Accuracy_LR))
# print("F1 score: " + str(F1_LR))
# print("Recall score: " + str(Recall_LR))
# print("Precision score: " + str(Precision_LR))

# print("zero value in validation set: ",sum(true==1))
# cm_2c = confusion_matrix(true, pred)
# cm_display_2c = ConfusionMatrixDisplay(cm_2c).plot()
# plt.show()
# Out:
# ####################
# Fold 1
# tensor([[-0.1631, -0.2355, -0.6114,  ...,  0.2227,  1.2796, -0.4306],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.3997, -0.8095,  1.4561],
#         [ 0.2471,  2.4561,  2.2423,  ..., -0.6080, -0.2835,  5.6753],
#         ...,
#         [-0.9019, -0.8933, -1.0569,  ..., -0.0259,  0.3998, -0.4294],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.1302, -0.4540, -0.4034],
#         [-0.8323, -0.9774, -0.7326,  ...,  0.2046, -0.1938, -0.4249]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 1.089315  [ 1024/52534]
# Test Error:
#  Accuracy: 76.1%, Avg loss: 0.578733
#
# Epoch 2
# -------------------------------
# loss: 0.604207  [ 1024/52534]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.525304
#
# Epoch 3
# -------------------------------
# loss: 0.503955  [ 1024/52534]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.452997
#
# Epoch 4
# -------------------------------
# loss: 0.419335  [ 1024/52534]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.415908
#
# Epoch 5
# -------------------------------
# loss: 0.417173  [ 1024/52534]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.403238
#
# Epoch 6
# -------------------------------
# loss: 0.395370  [ 1024/52534]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.371358
#
# Epoch 7
# -------------------------------
# loss: 0.351825  [ 1024/52534]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.384923
#
# Epoch 8
# -------------------------------
# loss: 0.351763  [ 1024/52534]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.347397
#
# Epoch 9
# -------------------------------
# loss: 0.304002  [ 1024/52534]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.340608
#
# Epoch 10
# -------------------------------
# loss: 0.301014  [ 1024/52534]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.318899
#
# Done!
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# Accuracy: 0.8877721943048577
# F1 score: 0.8877721943048577
# Recall score: 0.8877721943048577
# Precision score: 0.8877721943048577
# zero value in validation set:  4416
# ####################
# ####################
# Fold 2
# tensor([[-0.1631, -0.2355, -0.6114,  ...,  0.2227,  1.2796, -0.4306],
#         [ 0.2471,  2.4561,  2.2423,  ..., -0.6080, -0.2835,  5.6753],
#         [-1.0745, -0.8022, -0.7337,  ..., -0.0367,  0.6110, -0.4218],
#         ...,
#         [-1.0866, -0.9091, -0.9971,  ..., -0.4366,  0.6779, -0.3858],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.1302, -0.4540, -0.4034],
#         [-0.8323, -0.9774, -0.7326,  ...,  0.2046, -0.1938, -0.4249]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 0.276033  [ 1024/52534]
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.280031
#
# Epoch 2
# -------------------------------
# loss: 0.295463  [ 1024/52534]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.288255
#
# Epoch 3
# -------------------------------
# loss: 0.267790  [ 1024/52534]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.285338
#
# Epoch 4
# -------------------------------
# loss: 0.279020  [ 1024/52534]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.284315
#
# Epoch 5
# -------------------------------
# loss: 0.261680  [ 1024/52534]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.272357
#
# Epoch 6
# -------------------------------
# loss: 0.250689  [ 1024/52534]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.263240
#
# Epoch 7
# -------------------------------
# loss: 0.236510  [ 1024/52534]
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.260686
#
# Epoch 8
# -------------------------------
# loss: 0.226330  [ 1024/52534]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.278319
#
# Epoch 9
# -------------------------------
# loss: 0.231582  [ 1024/52534]
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.271256
#
# Epoch 10
# -------------------------------
# loss: 0.242938  [ 1024/52534]
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.243217
#
# Done!
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# Accuracy: 0.9205116491548653
# F1 score: 0.9205116491548653
# Recall score: 0.9205116491548653
# Precision score: 0.9205116491548653
# zero value in validation set:  4314
# ####################
# ####################
# Fold 3
# tensor([[ 1.3408,  1.0867,  1.8346,  ..., -0.3997, -0.8095,  1.4561],
#         [ 0.2471,  2.4561,  2.2423,  ..., -0.6080, -0.2835,  5.6753],
#         [-0.9834, -0.5189, -0.1630,  ..., -0.4072, -0.7911, -0.3966],
#         ...,
#         [ 0.4331,  0.2585,  0.6240,  ..., -0.2584, -0.0659, -0.3910],
#         [-0.9019, -0.8933, -1.0569,  ..., -0.0259,  0.3998, -0.4294],
#         [-1.0866, -0.9091, -0.9971,  ..., -0.4366,  0.6779, -0.3858]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 0.214178  [ 1024/52534]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.253430
#
# Epoch 2
# -------------------------------
# loss: 0.229731  [ 1024/52534]
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.232507
#
# Epoch 3
# -------------------------------
# loss: 0.224333  [ 1024/52534]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.242744
#
# Epoch 4
# -------------------------------
# loss: 0.215073  [ 1024/52534]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.233291
#
# Epoch 5
# -------------------------------
# loss: 0.227922  [ 1024/52534]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.227633
#
# Epoch 6
# -------------------------------
# loss: 0.221549  [ 1024/52534]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.240627
#
# Epoch 7
# -------------------------------
# loss: 0.217593  [ 1024/52534]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.237940
#
# Epoch 8
# -------------------------------
# loss: 0.217095  [ 1024/52534]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.231464
#
# Epoch 9
# -------------------------------
# loss: 0.220808  [ 1024/52534]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.247598
#
# Epoch 10
# -------------------------------
# loss: 0.217520  [ 1024/52534]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.241428
#
# Done!
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# Accuracy: 0.9155626617938176
# F1 score: 0.9155626617938176
# Recall score: 0.9155626617938176
# Precision score: 0.9155626617938176
# zero value in validation set:  4449
# ####################
# ####################
# Fold 4
# tensor([[-0.1631, -0.2355, -0.6114,  ...,  0.2227,  1.2796, -0.4306],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.3997, -0.8095,  1.4561],
#         [ 0.2471,  2.4561,  2.2423,  ..., -0.6080, -0.2835,  5.6753],
#         ...,
#         [-1.0866, -0.9091, -0.9971,  ..., -0.4366,  0.6779, -0.3858],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.1302, -0.4540, -0.4034],
#         [-0.8323, -0.9774, -0.7326,  ...,  0.2046, -0.1938, -0.4249]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 0.218163  [ 1024/52535]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.210122
#
# Epoch 2
# -------------------------------
# loss: 0.214572  [ 1024/52535]
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.221050
#
# Epoch 3
# -------------------------------
# loss: 0.214861  [ 1024/52535]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.207847
#
# Epoch 4
# -------------------------------
# loss: 0.194214  [ 1024/52535]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.229941
#
# Epoch 5
# -------------------------------
# loss: 0.205366  [ 1024/52535]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.225326
#
# Epoch 6
# -------------------------------
# loss: 0.197108  [ 1024/52535]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.213669
#
# Epoch 7
# -------------------------------
# loss: 0.180263  [ 1024/52535]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.226375
#
# Epoch 8
# -------------------------------
# loss: 0.227546  [ 1024/52535]
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.225853
#
# Epoch 9
# -------------------------------
# loss: 0.210093  [ 1024/52535]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.224428
#
# Epoch 10
# -------------------------------
# loss: 0.194530  [ 1024/52535]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.240131
#
# Done!
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# Accuracy: 0.9202771643950354
# F1 score: 0.9202771643950354
# Recall score: 0.9202771643950354
# Precision score: 0.9202771643950354
# zero value in validation set:  4446
# ####################
# ####################
# Fold 5
# tensor([[-0.1631, -0.2355, -0.6114,  ...,  0.2227,  1.2796, -0.4306],
#         [ 1.3408,  1.0867,  1.8346,  ..., -0.3997, -0.8095,  1.4561],
#         [-0.9834, -0.5189, -0.1630,  ..., -0.4072, -0.7911, -0.3966],
#         ...,
#         [-1.0866, -0.9091, -0.9971,  ..., -0.4366,  0.6779, -0.3858],
#         [ 2.9359, -0.3079,  0.1034,  ..., -0.1302, -0.4540, -0.4034],
#         [-0.8323, -0.9774, -0.7326,  ...,  0.2046, -0.1938, -0.4249]],
#        device='cuda:0')
# Epoch 1
# -------------------------------
# loss: 0.200799  [ 1024/52535]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.219845
#
# Epoch 2
# -------------------------------
# loss: 0.244732  [ 1024/52535]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.192138
#
# Epoch 3
# -------------------------------
# loss: 0.201454  [ 1024/52535]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.208022
#
# Epoch 4
# -------------------------------
# loss: 0.216952  [ 1024/52535]
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.212386
#
# Epoch 5
# -------------------------------
# loss: 0.189073  [ 1024/52535]
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.237179
#
# Epoch 6
# -------------------------------
# loss: 0.233179  [ 1024/52535]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.212169
#
# Epoch 7
# -------------------------------
# loss: 0.179199  [ 1024/52535]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.230191
#
# Epoch 8
# -------------------------------
# loss: 0.218247  [ 1024/52535]
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.214918
#
# Epoch 9
# -------------------------------
# loss: 0.211371  [ 1024/52535]
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.245159
#
# Epoch 10
# -------------------------------
# loss: 0.209416  [ 1024/52535]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.214250
#
# Done!
# DNN(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=180, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# Accuracy: 0.9318510622097007
# F1 score: 0.9318510622097007
# Recall score: 0.9318510622097007
# Precision score: 0.9318510622097007
# zero value in validation set:  4321
# ####################
# ####################
# The average accuracy is 0.9151949463716553
# ####################
# Accuracy: 0.8628822850548182
# F1 score: 0.8628822850548182
# Recall score: 0.8628822850548182
# Precision score: 0.8628822850548182
# zero value in validation set:  503

# %% [markdown]
# ## 5. Model Evaluation
